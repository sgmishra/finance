# %% [markdown]
# # API

# %% [markdown]
# ## API to fetch expiry of particular year
# ### Request
# https://www.nseindia.com/api/historical/foCPV/expireDts?instrument=OPTIDX&symbol=NIFTY&year=2014
# ### Response
# {"expiresDts":["30-Jan-2014","26-Feb-2014","27-Mar-2014","24-Apr-2014","29-May-2014","26-Jun-2014","31-Jul-2014","28-Aug-2014","25-Sep-2014","30-Oct-2014","27-Nov-2014","24-Dec-2014"]}

# %% [markdown]
# ## API to
# ### Request
# https://www.nseindia.com/api/historical/foCPV?from=01-04-2014&to=01-06-2014&instrumentType=OPTIDX&symbol=NIFTY&year=2014&expiryDate=26-Jun-2014&optionType=CE&csv=true
# ### Response
# {"data":[{"_id":"642c346de2684b2e013c91c1","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"9000","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":".05","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":".05","FH_SETTLE_PRICE":"0","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c91c5","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"8900","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":".35","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":".35","FH_SETTLE_PRICE":"0","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c91bf","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"8800","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"17.95","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"17.95","FH_SETTLE_PRICE":"0","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c91bd","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"8700","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"47.95","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"47.95","FH_SETTLE_PRICE":".05","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c91be","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"8600","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"741.55","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"741.55","FH_SETTLE_PRICE":".05","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c91c9","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"8500","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"198","FH_LAST_TRADED_PRICE":"198","FH_PREV_CLS":"198","FH_SETTLE_PRICE":".05","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"2000","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c91c7","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"8400","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"814.65","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"814.65","FH_SETTLE_PRICE":".1","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c91c8","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"8300","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"846.2","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"846.2","FH_SETTLE_PRICE":".2","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c91cf","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"8200","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"878.7","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"878.7","FH_SETTLE_PRICE":".35","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c91cb","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"8150","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":".55","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":".55","FH_SETTLE_PRICE":".45","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c91cc","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"8100","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"912.3","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"912.3","FH_SETTLE_PRICE":".65","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c91d2","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"8050","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"1","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"1","FH_SETTLE_PRICE":".85","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97a7","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"8000","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"23","FH_LAST_TRADED_PRICE":"23","FH_PREV_CLS":"23","FH_SETTLE_PRICE":"1.15","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"28150","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97b2","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"7950","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"1.75","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"1.75","FH_SETTLE_PRICE":"1.55","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97b0","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"7900","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"40","FH_LAST_TRADED_PRICE":"40","FH_PREV_CLS":"40","FH_SETTLE_PRICE":"2.05","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"400","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97b1","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"7850","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"2.95","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"2.95","FH_SETTLE_PRICE":"2.75","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97af","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"7800","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"40","FH_LAST_TRADED_PRICE":"40","FH_PREV_CLS":"40","FH_SETTLE_PRICE":"3.6","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"1000","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97b4","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"7750","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"4.85","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"4.85","FH_SETTLE_PRICE":"4.75","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97b6","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"7700","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"30","FH_LAST_TRADED_PRICE":"30","FH_PREV_CLS":"30","FH_SETTLE_PRICE":"6.15","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"3150","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97b7","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"7650","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"7.9","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"7.9","FH_SETTLE_PRICE":"7.95","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97b9","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"7600","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"50","FH_TRADE_HIGH_PRICE":"55","FH_TRADE_LOW_PRICE":"50","FH_CLOSING_PRICE":"55","FH_LAST_TRADED_PRICE":"55","FH_PREV_CLS":"50","FH_SETTLE_PRICE":"55","FH_TOT_TRADED_QTY":"150","FH_TOT_TRADED_VAL":"1147800","FH_OPEN_INT":"14150","FH_CHANGE_IN_OI":"150","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97bb","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"7550","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"12.5","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"12.5","FH_SETTLE_PRICE":"13","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97bd","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"7500","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"65","FH_TRADE_HIGH_PRICE":"67","FH_TRADE_LOW_PRICE":"58","FH_CLOSING_PRICE":"65.55","FH_LAST_TRADED_PRICE":"67","FH_PREV_CLS":"68.9","FH_SETTLE_PRICE":"65.55","FH_TOT_TRADED_QTY":"4750","FH_TOT_TRADED_VAL":"35925987.5","FH_OPEN_INT":"318900","FH_CHANGE_IN_OI":"1350","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97c0","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"7450","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"19.35","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"19.35","FH_SETTLE_PRICE":"20.6","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97cb","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"7400","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"85","FH_TRADE_HIGH_PRICE":"87.25","FH_TRADE_LOW_PRICE":"64.35","FH_CLOSING_PRICE":"87.25","FH_LAST_TRADED_PRICE":"87.25","FH_PREV_CLS":"89.2","FH_SETTLE_PRICE":"87.25","FH_TOT_TRADED_QTY":"550","FH_TOT_TRADED_VAL":"4114145","FH_OPEN_INT":"45050","FH_CHANGE_IN_OI":"200","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97c3","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"7350","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"29.25","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"29.25","FH_SETTLE_PRICE":"31.8","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97c5","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"7300","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"113","FH_TRADE_HIGH_PRICE":"113","FH_TRADE_LOW_PRICE":"100","FH_CLOSING_PRICE":"100","FH_LAST_TRADED_PRICE":"100","FH_PREV_CLS":"113.5","FH_SETTLE_PRICE":"100","FH_TOT_TRADED_QTY":"150","FH_TOT_TRADED_VAL":"1110650","FH_OPEN_INT":"11000","FH_CHANGE_IN_OI":"50","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97c6","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"7250","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"43.05","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"43.05","FH_SETTLE_PRICE":"47.6","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97c9","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"7200","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"132","FH_TRADE_HIGH_PRICE":"149.95","FH_TRADE_LOW_PRICE":"129","FH_CLOSING_PRICE":"140.9","FH_LAST_TRADED_PRICE":"144.75","FH_PREV_CLS":"141.4","FH_SETTLE_PRICE":"140.9","FH_TOT_TRADED_QTY":"5850","FH_TOT_TRADED_VAL":"42927332.5","FH_OPEN_INT":"23650","FH_CHANGE_IN_OI":"-3150","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97cd","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"7150","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"61.8","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"61.8","FH_SETTLE_PRICE":"69.25","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97d2","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"7100","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"178.2","FH_TRADE_HIGH_PRICE":"178.2","FH_TRADE_LOW_PRICE":"166","FH_CLOSING_PRICE":"166","FH_LAST_TRADED_PRICE":"166","FH_PREV_CLS":"178.1","FH_SETTLE_PRICE":"166","FH_TOT_TRADED_QTY":"650","FH_TOT_TRADED_VAL":"4723930","FH_OPEN_INT":"41300","FH_CHANGE_IN_OI":"-500","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97cf","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"7050","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"191.6","FH_TRADE_HIGH_PRICE":"191.6","FH_TRADE_LOW_PRICE":"191.6","FH_CLOSING_PRICE":"191.6","FH_LAST_TRADED_PRICE":"191.6","FH_PREV_CLS":"190","FH_SETTLE_PRICE":"191.6","FH_TOT_TRADED_QTY":"2000","FH_TOT_TRADED_VAL":"14483200","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"-2000","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97d1","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"7000","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"219","FH_TRADE_HIGH_PRICE":"219","FH_TRADE_LOW_PRICE":"200","FH_CLOSING_PRICE":"214.9","FH_LAST_TRADED_PRICE":"216","FH_PREV_CLS":"217.95","FH_SETTLE_PRICE":"214.9","FH_TOT_TRADED_QTY":"84150","FH_TOT_TRADED_VAL":"606565425","FH_OPEN_INT":"465150","FH_CHANGE_IN_OI":"5400","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97d4","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"6950","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"118.4","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"118.4","FH_SETTLE_PRICE":"134.8","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97d6","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"6900","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"250","FH_TRADE_HIGH_PRICE":"255","FH_TRADE_LOW_PRICE":"242","FH_CLOSING_PRICE":"255","FH_LAST_TRADED_PRICE":"255","FH_PREV_CLS":"260.45","FH_SETTLE_PRICE":"255","FH_TOT_TRADED_QTY":"250","FH_TOT_TRADED_VAL":"1787252.5","FH_OPEN_INT":"5050","FH_CHANGE_IN_OI":"200","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97d8","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"6850","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"158.05","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"158.05","FH_SETTLE_PRICE":"180.45","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97da","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"6800","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"285","FH_TRADE_HIGH_PRICE":"309.95","FH_TRADE_LOW_PRICE":"285","FH_CLOSING_PRICE":"308.35","FH_LAST_TRADED_PRICE":"308","FH_PREV_CLS":"309.55","FH_SETTLE_PRICE":"308.35","FH_TOT_TRADED_QTY":"4250","FH_TOT_TRADED_VAL":"30179707.5","FH_OPEN_INT":"46450","FH_CHANGE_IN_OI":"350","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97dc","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"6750","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"241.5","FH_LAST_TRADED_PRICE":"241.5","FH_PREV_CLS":"241.5","FH_SETTLE_PRICE":"235.2","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"50","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97de","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"6700","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"355","FH_TRADE_HIGH_PRICE":"364.6","FH_TRADE_LOW_PRICE":"339.2","FH_CLOSING_PRICE":"358.8","FH_LAST_TRADED_PRICE":"362.05","FH_PREV_CLS":"361.55","FH_SETTLE_PRICE":"358.8","FH_TOT_TRADED_QTY":"14800","FH_TOT_TRADED_VAL":"104401842.5","FH_OPEN_INT":"288850","FH_CHANGE_IN_OI":"4700","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97df","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"6650","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"262.7","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"262.7","FH_SETTLE_PRICE":"298.8","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97e2","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"6600","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"417.35","FH_TRADE_HIGH_PRICE":"471.05","FH_TRADE_LOW_PRICE":"392.6","FH_CLOSING_PRICE":"417.95","FH_LAST_TRADED_PRICE":"422","FH_PREV_CLS":"430","FH_SETTLE_PRICE":"417.95","FH_TOT_TRADED_QTY":"2450","FH_TOT_TRADED_VAL":"17182732.5","FH_OPEN_INT":"73450","FH_CHANGE_IN_OI":"1050","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97e4","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"6550","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"327.55","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"327.55","FH_SETTLE_PRICE":"370.75","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97e6","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"6500","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"480","FH_TRADE_HIGH_PRICE":"487.6","FH_TRADE_LOW_PRICE":"455.1","FH_CLOSING_PRICE":"484.45","FH_LAST_TRADED_PRICE":"485","FH_PREV_CLS":"480.75","FH_SETTLE_PRICE":"484.45","FH_TOT_TRADED_QTY":"41000","FH_TOT_TRADED_VAL":"285916340","FH_OPEN_INT":"843800","FH_CHANGE_IN_OI":"-15800","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97e9","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"6450","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"400.1","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"400.1","FH_SETTLE_PRICE":"449.8","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97ea","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"6400","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"538.4","FH_TRADE_HIGH_PRICE":"539.15","FH_TRADE_LOW_PRICE":"509.95","FH_CLOSING_PRICE":"509.95","FH_LAST_TRADED_PRICE":"509.95","FH_PREV_CLS":"553.5","FH_SETTLE_PRICE":"509.95","FH_TOT_TRADED_QTY":"250","FH_TOT_TRADED_VAL":"1733242.5","FH_OPEN_INT":"28900","FH_CHANGE_IN_OI":"200","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97eb","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"6350","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"479.25","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"479.25","FH_SETTLE_PRICE":"534.7","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97ee","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"6300","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"600","FH_TRADE_HIGH_PRICE":"600","FH_TRADE_LOW_PRICE":"600","FH_CLOSING_PRICE":"600","FH_LAST_TRADED_PRICE":"600","FH_PREV_CLS":"600","FH_SETTLE_PRICE":"600","FH_TOT_TRADED_QTY":"2750","FH_TOT_TRADED_VAL":"18975000","FH_OPEN_INT":"27150","FH_CHANGE_IN_OI":"-50","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97f0","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"6250","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"563.9","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"563.9","FH_SETTLE_PRICE":"624.1","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97f6","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"6200","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"690","FH_TRADE_HIGH_PRICE":"690","FH_TRADE_LOW_PRICE":"673.55","FH_CLOSING_PRICE":"677.95","FH_LAST_TRADED_PRICE":"677.95","FH_PREV_CLS":"690","FH_SETTLE_PRICE":"677.95","FH_TOT_TRADED_QTY":"850","FH_TOT_TRADED_VAL":"5853650","FH_OPEN_INT":"9200","FH_CHANGE_IN_OI":"250","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97f3","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"6150","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"652.85","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"652.85","FH_SETTLE_PRICE":"716.75","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97fc","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"6100","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"765.25","FH_TRADE_HIGH_PRICE":"766.1","FH_TRADE_LOW_PRICE":"765.25","FH_CLOSING_PRICE":"766.1","FH_LAST_TRADED_PRICE":"766.1","FH_PREV_CLS":"651.05","FH_SETTLE_PRICE":"766.1","FH_TOT_TRADED_QTY":"1700","FH_TOT_TRADED_VAL":"11671520","FH_OPEN_INT":"3700","FH_CHANGE_IN_OI":"1600","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97f7","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"6050","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"745","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"745","FH_SETTLE_PRICE":"811.6","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97f8","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"6000","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"854.45","FH_TRADE_HIGH_PRICE":"865","FH_TRADE_LOW_PRICE":"810","FH_CLOSING_PRICE":"848.45","FH_LAST_TRADED_PRICE":"848.7","FH_PREV_CLS":"842.5","FH_SETTLE_PRICE":"848.45","FH_TOT_TRADED_QTY":"20500","FH_TOT_TRADED_VAL":"140146607.5","FH_OPEN_INT":"266250","FH_CHANGE_IN_OI":"-7200","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97fb","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"5950","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"839.35","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"839.35","FH_SETTLE_PRICE":"907.8","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97fe","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"5900","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"1341.3","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"1341.3","FH_SETTLE_PRICE":"956.2","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c9804","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"5850","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"935.15","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"935.15","FH_SETTLE_PRICE":"1004.75","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c9801","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"5800","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"783.1","FH_LAST_TRADED_PRICE":"783.1","FH_PREV_CLS":"783.1","FH_SETTLE_PRICE":"1053.4","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"1850","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c97ff","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"5750","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"1031.75","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"1031.75","FH_SETTLE_PRICE":"1102.15","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c9806","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"5700","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"1301.35","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"1301.35","FH_SETTLE_PRICE":"1150.9","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c9808","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"5650","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"1128.9","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"1128.9","FH_SETTLE_PRICE":"1199.75","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c9812","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"5600","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"600","FH_LAST_TRADED_PRICE":"600","FH_PREV_CLS":"600","FH_SETTLE_PRICE":"1248.55","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c980d","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"5550","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"1226.25","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"1226.25","FH_SETTLE_PRICE":"1297.4","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c980b","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"5500","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"1248.3","FH_LAST_TRADED_PRICE":"1248.3","FH_PREV_CLS":"1248.3","FH_SETTLE_PRICE":"1346.25","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"79550","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c980f","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"5450","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"1323.75","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"1323.75","FH_SETTLE_PRICE":"1395.1","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c9810","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"5400","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"1241.55","FH_LAST_TRADED_PRICE":"1250","FH_PREV_CLS":"1241.55","FH_SETTLE_PRICE":"1443.95","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"650","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c9814","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"5350","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"1421.3","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"1421.3","FH_SETTLE_PRICE":"1492.8","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c981a","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"5300","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"1320","FH_LAST_TRADED_PRICE":"1320","FH_PREV_CLS":"1320","FH_SETTLE_PRICE":"1541.7","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"22750","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c981e","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"5250","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"1518.9","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"1518.9","FH_SETTLE_PRICE":"1590.55","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c9817","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"5200","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"1427.8","FH_LAST_TRADED_PRICE":"1427.8","FH_PREV_CLS":"1427.8","FH_SETTLE_PRICE":"1639.4","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"185750","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"},{"_id":"642c346de2684b2e013c981b","FH_INSTRUMENT":"OPTIDX","FH_SYMBOL":"NIFTY","FH_EXPIRY_DT":"26-Jun-2014","FH_STRIKE_PRICE":"5150","FH_OPTION_TYPE":"CE","FH_MARKET_TYPE":"N","FH_OPENING_PRICE":"0","FH_TRADE_HIGH_PRICE":"0","FH_TRADE_LOW_PRICE":"0","FH_CLOSING_PRICE":"1616.45","FH_LAST_TRADED_PRICE":"0","FH_PREV_CLS":"1616.45","FH_SETTLE_PRICE":"1688.25","FH_TOT_TRADED_QTY":"0","FH_TOT_TRADED_VAL":"0","FH_OPEN_INT":"0","FH_CHANGE_IN_OI":"0","FH_MARKET_LOT":"50","FH_TIMESTAMP":"01-Apr-2014","FH_UNDERLYING_VALUE":"6721.05","TIMESTAMP":"2014-03-31T18:30:00.000Z"}]}

# %% [markdown]
# ## API to
# ### Request
#
# ### Response

# %% [markdown]
# ## API to
# ### Request
#
# ### Response

# %% [markdown]
# ## API to
# ### Request
#
# ### Response

# %% [markdown]
# ## API to
# ### Request
#
# ### Response

# %% [markdown]
# ## API to
# ### Request
#
# ### Response
