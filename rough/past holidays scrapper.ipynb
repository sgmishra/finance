# %% [markdown]
# ## Download historila holidays

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# URL of the webpage to download
for year in [2013, 2014, 2015, 2016, 2018, 2019, 2020, 2021]:
    url = 'https://zerodha.com/z-connect/general/trading-holidays-{}-nse-bse-mcx'.format(year)
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    tables = soup.find_all('table')
    print(pd.read_html(str(tables[0]))[0].append(pd.read_html(str(tables[1]))[0], ignore_index=True))
# Out:
#      0                       1             2            3
# 0   s#                Holidays          Date  Day of Week
# 1    1            Republic Day  Jan 26, 2013     Saturday
# 2    2                    Holi  Mar 27, 2013    Wednesday
# 3    3             Good Friday  Mar 29, 2013       Friday
# 4    4              Ram Navami  Apr 19, 2013       Friday
# 5    5         Mahavir Jayanti  Apr 24, 2013    Wednesday
# 6    6                 May Day   May 1, 2013    Wednesday
# 7    7               Ramzan ID   Aug 9, 2013       Friday
# 8    8        Independence Day  Aug 15, 2013     Thursday
# 9    9        Ganesh Chaturthi  Sept 9, 2013       Monday
# 10  10          Gandhi Jayanti   Oct 2, 2013    Wednesday
# 11  11                Bakri ID  Oct 16, 2013    Wednesday
# 12  12  Diwali – Balipratipada   Nov 4, 2013       Monday
# 13  13                Muharram  Nov 14, 2013     Thursday
# 14  14               Christmas  Dec 25, 2013    Wednesday
# ...

# %%
list(range(2013,2022,1))
# Out:
# [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

# %%
for i, table in enumerate(tables):
    # Convert table to DataFrame

# %%
# Out:
#      0                       1             2            3
# 0   s#                Holidays          Date  Day of Week
# 1    1            Republic Day  Jan 26, 2013     Saturday
# 2    2                    Holi  Mar 27, 2013    Wednesday
# 3    3             Good Friday  Mar 29, 2013       Friday
# 4    4              Ram Navami  Apr 19, 2013       Friday
# 5    5         Mahavir Jayanti  Apr 24, 2013    Wednesday
# 6    6                 May Day   May 1, 2013    Wednesday
# 7    7               Ramzan ID   Aug 9, 2013       Friday
# 8    8        Independence Day  Aug 15, 2013     Thursday
# 9    9        Ganesh Chaturthi  Sept 9, 2013       Monday
# 10  10          Gandhi Jayanti   Oct 2, 2013    Wednesday
# 11  11                Bakri ID  Oct 16, 2013    Wednesday
# 12  12  Diwali – Balipratipada   Nov 4, 2013       Monday
# 13  13                Muharram  Nov 14, 2013     Thursday
# 14  14               Christmas  Dec 25, 2013    Wednesday
# ...

# %%
for i, table in enumerate(tables):
    # Convert table to DataFrame
    df = pd.read_html(str(table))[0]

# %%
# Check if the request was successful
if response.status_code == 200:
    # Parse HTML content
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find all tables in the HTML
    tables = soup.find_all('table')
    
    # Loop through each table
    for i, table in enumerate(tables):
        # Convert table to DataFrame
        df = pd.read_html(str(table))[0]  # Use read_html to convert the table into a DataFrame
        
        # Save DataFrame to CSV
        df.to_csv(f'table_{i}.csv', index=False)  # Save each table as a separate CSV file
else:
    print("Failed to retrieve the webpage.")

# %%
print()
# Out:
#   S#
# Holidays
# Date
# Day of Week
